# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-151bc51a-9b26-4d8b-a104-0cda60d0d84d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-151bc51a-9b26-4d8b-a104-0cda60d0d84d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = pd.read_csv("skill_gap_dataset.csv")

data.head()
# Out:
#           Skill_Name  Curriculum_Coverage  Industry_Demand  Job_Frequency  \
# 0      C Programming                    5                3              6
# 1               Java                    5                5             10
# 2             Python                    4                5             10
# 3               DBMS                    5                4              8
# 4  Operating Systems                    5                4              7
#
#    Expert_Importance Gap_Status
# 0                  3    Aligned
# 1                  5    Aligned
# 2                  5    Aligned
# 3                  4    Aligned
# 4                  4    Aligned

# %%
data.info()
data.describe()
data.isnull().sum()
data.duplicated().sum()
print("Rows and Columns:", data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Skill_Name           24 non-null     object
#  1   Curriculum_Coverage  24 non-null     int64
#  2   Industry_Demand      24 non-null     int64
#  3   Job_Frequency        24 non-null     int64
#  4   Expert_Importance    24 non-null     int64
#  5   Gap_Status           24 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 1.3+ KB
# Rows and Columns: (24, 6)

# %%
# Convert target labels into numeric values
data["Gap_Status"] = data["Gap_Status"].map({
    "Aligned": 1,
    "Gap": 0
})

# Check the updated dataset
data.head()



print(data["Gap_Status"].value_counts())
# Out:
# Gap_Status
# 1    12
# 0    12
# Name: count, dtype: int64

# %%
# !git config --global user.name "Shomyaaraj"
# !git config --global user.email "shomya725@gmail.com"

# %%
# !git clone https://github.com/Shomyaaraj/MLoops.git
# Out:
# Cloning into 'MLoops'...
# ...

# %%
# %cd Curriculum-Industry-Skill-Gap-ML
# Out:
# /content/Curriculum-Industry-Skill-Gap-ML
